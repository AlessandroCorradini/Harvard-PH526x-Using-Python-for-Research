# %% [markdown]
# ## Part 1: Score Rules and Classes

# %% [markdown]
# ### CC 2.1.1: Scope Rules
#
# #### Scope Rules: Question 1
#
# Consider the following code:
#
# ```
# def increment(n):
#    n += 1
#    print(n)
#
# n = 1
# increment(n)
# print(n)
# ```
#
# What will this print? Note that here, we separate lines of output with "; "
#
# - 1 ; 1
# - **2 ; 1**
# - 1 ; 2
# - 2 ; 2
#
# ####  Scope Rules: Question 2
#
# Consider the following code:
#
# ```
# def increment(n):
#    n += 1
#    #blank#
#
# n = 1
# while n < 10:
#    n = increment(n)
# print(n)
# ```
#
# Fill in the #blank# to ensure this prints 10.
#
# Enter your code here.
#
# **```return n```**

# %% [markdown]
# ### CC 2.1.2: Classes and Object-Oriented Programming
#
# #### Classes and Object-Oriented Programming: Question 1
#
# Consider the following code:
#
# ```
# class NewList(list):
#    def remove_max(self):
#      self.remove(max(self))
#    def append_sum(self):
#      self.append(sum(self))
#
# x = NewList([1,2,3])
# while max(x) < 10:
#    x.remove_max()
#    x.append_sum()
# print(x)
# ```
#
# What will this print?
#
# - 10
# - [5,8,10]
# - Nothing: this code contains an error.
# - **Nothing: this program will never halt.**

# %% [markdown]
# ## Part 2: NumPy

# %% [markdown]
# ### CC 2.2.1: Introduction to NumPy Arrays
#
# #### Introduction to NumPy Arrays: Question 1
#
# True or False: a numpy array's length may be edited after being created.
#
# - True
# - **False**
#
# #### Introduction to NumPy Arrays: Question 2
#
# What code will produce the following object?
#
# ```
# numpy.array([0., 0., 0., 0., 0.])
# ```
#
# - **```numpy.zeros(5)```**
# - ```numpy.zeros(5, 0.)```
# - ```numpy.zeros(0,0,0,0,0)```
# - ```numpy.array(0,0,0,0,0)```
#
# #### Introduction to NumPy Arrays: Question 3
#
# Consider the following code:
#
# ```
# x = numpy.array([[3,6],[5,7]])
# y = x.transpose()
# print(y)
# ```
#
# What does this print?
#
# - ```array([[5 7],[3 6]])```
# - **```array([[3 5],[6 7]])```**
# - ```array([[3 6],[5 7]])```
# - ```array([[3 7],[5 6]])```
# - This code contains an error.

# %% [markdown]
# ### CC 2.2.2: Slicing NumPy Arrays
#
# #### Slicing NumPy Arrays: Question 1
#
# Consider the following code:
#
# ```
# x = np.array([1,2,5])
# x[1:2]
# ```
#
# What does this return?
#
# - ```np.array([1, 2])```
# - ```np.array([2, 5])
# - **```np.array([1])```**
# - ```np.array([2])```
# - This code contains an error.
#
# #### Slicing NumPy Arrays: Question 2
#
# Consider the following code:
#
# ```
# a = np.array([1,2])
# b = np.array([3,4,5])
# a + b
# ```
#
# What does this return?
#
# - ```np.array([1, 2, 3, 4, 5])```
# - ```np.array([4, 6, 5])```
# - ```np.array([4, 6])```
# - **This code contains an error.**

# %% [markdown]
# ### CC 2.2.3: Indexing NumPy Arrays
#
# #### Indexing NumPy Arrays: Question 1
#
# Consider the following code:
#
# ```
# a = np.array([1,2])
# b = np.array([3,4,5])
# b[a]
# ```
#
# What does this return?
#
# - ```np.array([1, 2, 3, 4, 5])```
# - ```np.array([4, 6, 5])```
# - **```np.array([4, 5])```**
# - This code contains an error.
#
# #### Indexing NumPy Arrays: Question 2
#
# Consider again the above code, as well as the following:
#
# ```
# c = b[1:]
# b[a] is c
# ```
#
# What does this return?
#
# - True
# - **False**
# - This code contains an error.

# %% [markdown]
# ### CC 2.2.4: Building and Examining NumPy Arrays
#
# #### Building and Examining NumPy Arrays: Question 1
#
# Consider the following code:
#
# ```
# x=20
# not np.any([x%i == 0 for i in range(2, x)])
# ```
# What does the above code do?
#
# - Finds whether x is 0 .
# - Finds whether x contains 0 .
# - Finds whether x is even.
# - **Finds whether x is prime.**

# %% [markdown]
# ## Part 3: Matplotlib and Pyplot

# %% [markdown]
# ### CC 2.3.1: Introduction to Matplotlib and Pyplot
#
# #### Introduction to Matplotlib and Pyplot: Question 1
#
# What does ```plt.show()``` do?
#
# - Create a plot, and print if desired.
# - Return a plot, and print if desired.
# - **Show a plot that is already created.*
#
# #### Introduction to Matplotlib and Pyplot: Question 2
#
# What does ```plt.plot([0,1,2],[0,1,4],"rd-")``` do?
#
# - A plot of a smooth curve, and red dots at the endpoints.
# - A plot of two connected lines, and red dots at the junctures.
# - **A plot of two connected lines, with red diamonds at the junctures.**
# - This code contains an error.

# %% [markdown]
# ### CC 2.3.3: Plotting Using Logarithmic Axes
#
# #### Plotting Using Logarithmic Axes: Question 1
#
# Consider the following code:
#
# ```
# x=np.logspace(0,1,10)
# y=x**2
# plt.loglog(x,y,"bo-")
# ```
#
# What does this return?
#
# - A logarithmic plot, which looks like a quadratic function with logarithmic spacing.
# - A logarithmic plot, which looks like a quadratic function with equal spacing.
# - A logarithmic plot, which looks like a straight line with logarithmic spacing.
# - **A logarithmic plot, which looks like a straight line with equal spacing.**

# %% [markdown]
# ### CC 2.3.4: Generating Histograms
#
# #### Generating Histograms: Question 1
#
# Which will have wider bins, ```np.linspace(-5,5,21)``` or ```np.linspace(-5,5,201)```?
#
# - **```np.linspace(-5,5,21)```**
# - ```np.linspace(-5,5,201)```
#
# #### Generating Histograms: Question 2
#
# What will ```plt.subplot(333)``` do?
#
# - Create a blank plot that fills the figure.
# - Create a plot with three points at location (3,3).
# - Create a smaller subplot in the topleft of the figure.
# - **Create a smaller subplot in the topright of the figure.**
#
# #### Generating Histograms: Question 3
#
# Will ```plt.subplot(3, 3, 3)``` create a different plot from ```plt.subplot(333)```?
#
# - Yes
# - **No**

# %% [markdown]
# ## Part 4: Randomness and Time

# %% [markdown]
# ### CC 2.4.1: Simulating Randomness
#
# #### Simulating Randomness: Question 1
#
# Use ```random.choice``` and range to generate a random integer from 0-9.
#
# Enter your code here.
#
# **```random.choice(range(0,10))```**
#
# #### Simulating Randomness: Question 2
#
# What will ```random.choice(list([1,2,3,4]))``` produce?
#
# - ```list([1,2,3,4])```
# - ```[1,2,3,4]```
# - A value from 1-4 , selected at random. correct
# - This code contains an error.
#
# #### Simulating Randomness: Question 3
#
# Which of the following lines of code sums random integers from 0-9?
#
# - ```sum(random.sample(range(10),10))```
# - ```sum(random.choice(range(10),10))```
# - ```random.sample_sum(range(10), 10)```
# - **```sum(random.choice(range(10)) for i in range(10))```**

# %% [markdown]
# ### CC 2.4.2: Examples Using Randomness
#
# #### Examples Using Randomness: Question 1
#
# What will ```random.choice(list((1,2,3,4)))``` do?
#
# - Sample the tuple (1,2,3,4) .
# - Sample the list [1,2,3,4] .
# - Sample from the tuple (1,2,3,4) .
# - **Sample from the list [1,2,3,4] .**
# - This code contains an error.
#
# #### Examples Using Randomness: Question 2
#
# What is the law of large numbers with respect to histograms?
#
# - **We expect the histogram of a sample to better reflect the distribution as the sample size increases.**
# - We expect the histogram of a sample to become more smooth as the sample size increases.
# - We expect the histogram of a sample to become more flat as the sample size increases.
# - All numbers in the histogram are very large, by law.
#
# #### Examples Using Randomness: Question 3
#
# What is the Central Limit Theorem?
#
# - The distribution of many random variables is approximately normal.
# - The distribution of many numbers numbers is approximately normal.
# - **The distribution of the sum of many random variables is approximately normal.**
# - The distribution of the sum of many numbers is approximately normal.

# %% [markdown]
# ### CC 2.4.3: Using the NumPy Random Module
#
# #### Using the NumPy Random Module: Question 1
#
# What does ```numpy.random.random((5,2,3))``` do?
#
# - Generate a random value from the tuple (5,2,3) .
# - **Generate a 5 x 2 x 3 NumPy array with random uniform values.**
# - Generate 3 values from the normal distribution with mean 2 and variance 3.
#
# #### Using the NumPy Random Module: Question 2
#
# What does ```numpy.random.normal(1,2,3)``` do?
#
# - Generate 3 samples with mean 1 and variance 2.
# - **Generate 3 samples with mean 1 and standard deviation 2.**
# - Generate 3 samples with variance 1 and mean 2.
# - Generate 3 samples with standard deviation 1 and mean 2.
# - Generate 1 sample with mean 2 and standard deviation 3.
#
# #### Using the NumPy Random Module: Question 3
#
# What does ```numpy.random.randint(1,5,(2,3))``` do?
#
# - Sample a random value from 1 , 5 , and (2,3) .
# - Sample a random integer from 1 , 2 , 3 , and 5 .
# - **Generate a 2 x 3 array with random integers from 1-4**
# - This code contains an error.
#
# #### Using the NumPy Random Module: Question 4
#
# What is the dimension of ```numpy.sum(numpy.random.randint(1,7,(100,10)), axis=0)```?
#
# - 1
# - 7
# - **10**
# - 100
# - 10 x 100
# - 100 x 10

# %% [markdown]
# ### CC 2.4.4: Measuring Time
#
# #### Measuring Time: Question 1
#
# Consider the following code:
#
# ```
# start_time = time.clock()
# stop_time = time.clock()
# stop_time - start_time
# ```
#
# What does this return?
#
# - An int of the seconds between the two times.
# - **A float of the seconds between the two times.**
# - A string of the seconds between the two times.
# - This code contains an error.

# %% [markdown]
# ### CC 2.4.5: Random Walks
#
# #### Random Walks: Question 1
#
# How is the location for each step in a random walk related to the locations for other steps?
#
# - They are random, and therefore unrelated.
# - **They are identical to the previous step, plus random noise.**
# - They follow along one of many determined paths, selected at random.
#
# #### Random Walks: Question 2
#
# What does np.concatenate do?
#
# - **Takes an iterable of np.arrays as arguments, and binds them along the axis argument.**
# - Takes any number of np.array arguments, and binds them along the axis argument.
# - Takes an iterable of np.arrays as arguments, and sums them along the axis argument.
# - Takes any number of np.array arguments, and sums them along the axis argument.
